# %% [markdown]
# <a href="https://colab.research.google.com/github/darlaabril/Taller-Python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas

# %% [markdown]
# Importar pandas

# %%
import pandas as pd

# %% [markdown]
# Crear dataframe

# %%
##Forma 1
nombres_columnas = ['Departamento', 'Provincia']

obs1 = ['Amazonas', 'Chachapoyas']
obs2 = ['Cajamarca',  'Chota']

data = [obs1, obs2]

ejemplo_df = pd.DataFrame(data = data, columns = nombres_columnas)
ejemplo_df
# Out:
#   Departamento    Provincia
# 0     Amazonas  Chachapoyas
# 1    Cajamarca        Chota

# %%
##Forma 2
df = pd.DataFrame()
df['Departamento'] = ['Amazonas', 'Cajamarca']
df['Provincia'] = [ 'Chachapoyas' , 'Chota']
df['Distrito'] = ["Asuncion", "Chadin"]

df
# Out:
#   Departamento    Provincia  Distrito
# 0     Amazonas  Chachapoyas  Asuncion
# 1    Cajamarca        Chota    Chadin

# %% [markdown]
# Leer Informacion

# %%
locacion_datos = "https://raw.githubusercontent.com/andrealivia49/Python/main/ubigeos_v1.xlsx%20-%20TB_UBIGEOS.csv"
ndf = pd.read_csv(locacion_datos)
ndf
# Out:
#                            CONCATENADOS  id_ubigeo  ubigeo_reniec  \
# 0        AMAZONASCHACHAPOYASCHACHAPOYAS          1        10101.0
# 1           AMAZONASCHACHAPOYASASUNCION          2        10102.0
# 2             AMAZONASCHACHAPOYASBALSAS          3        10103.0
# 3              AMAZONASCHACHAPOYASCHETO          4        10104.0
# 4          AMAZONASCHACHAPOYASCHILIQUIN          5        10105.0
# ...                                 ...        ...            ...
# 1888               TUMBESTUMBESCORRALES       1847       230102.0
# 1889                TUMBESTUMBESLA CRUZ       1848       230103.0
# 1890     TUMBESTUMBESPAMPAS DE HOSPITAL       1849       230104.0
# 1891            TUMBESTUMBESSAN JACINTO       1850       230105.0
# 1892  TUMBESTUMBESSAN JUAN DE LA VIRGEN       1851       230106.0
#
#       ubigeo_inei  departamento_inei departamento  provincia_inei  \
# 0         10101.0                  1     AMAZONAS             101
# ...

# %%
## Primeras observaciones
ndf.head()
# Out:
#                      CONCATENADOS  id_ubigeo  ubigeo_reniec  ubigeo_inei  \
# 0  AMAZONASCHACHAPOYASCHACHAPOYAS          1        10101.0      10101.0
# 1     AMAZONASCHACHAPOYASASUNCION          2        10102.0      10102.0
# 2       AMAZONASCHACHAPOYASBALSAS          3        10103.0      10103.0
# 3        AMAZONASCHACHAPOYASCHETO          4        10104.0      10104.0
# 4    AMAZONASCHACHAPOYASCHILIQUIN          5        10105.0      10105.0
#
#    departamento_inei departamento  provincia_inei    provincia     distrito  \
# 0                  1     AMAZONAS             101  CHACHAPOYAS  CHACHAPOYAS
# 1                  1     AMAZONAS             101  CHACHAPOYAS     ASUNCION
# 2                  1     AMAZONAS             101  CHACHAPOYAS       BALSAS
# 3                  1     AMAZONAS             101  CHACHAPOYAS        CHETO
# 4                  1     AMAZONAS             101  CHACHAPOYAS    CHILIQUIN
#
#      region macroregion_inei    macroregion_minsa iso_3166_2  fips  \
# ...

# %%
## Ultimas observaciones
ndf.tail()
# Out:
#                            CONCATENADOS  id_ubigeo  ubigeo_reniec  \
# 1888               TUMBESTUMBESCORRALES       1847       230102.0
# 1889                TUMBESTUMBESLA CRUZ       1848       230103.0
# 1890     TUMBESTUMBESPAMPAS DE HOSPITAL       1849       230104.0
# 1891            TUMBESTUMBESSAN JACINTO       1850       230105.0
# 1892  TUMBESTUMBESSAN JUAN DE LA VIRGEN       1851       230106.0
#
#       ubigeo_inei  departamento_inei departamento  provincia_inei provincia  \
# 1888     240102.0                 24       TUMBES            2401    TUMBES
# 1889     240103.0                 24       TUMBES            2401    TUMBES
# 1890     240104.0                 24       TUMBES            2401    TUMBES
# 1891     240105.0                 24       TUMBES            2401    TUMBES
# 1892     240106.0                 24       TUMBES            2401    TUMBES
#
#                    distrito  region macroregion_inei  macroregion_minsa  \
# ...

# %%
ndf.head(3)
# Out:
#                      CONCATENADOS  id_ubigeo  ubigeo_reniec  ubigeo_inei  \
# 0  AMAZONASCHACHAPOYASCHACHAPOYAS          1        10101.0      10101.0
# 1     AMAZONASCHACHAPOYASASUNCION          2        10102.0      10102.0
# 2       AMAZONASCHACHAPOYASBALSAS          3        10103.0      10103.0
#
#    departamento_inei departamento  provincia_inei    provincia     distrito  \
# 0                  1     AMAZONAS             101  CHACHAPOYAS  CHACHAPOYAS
# 1                  1     AMAZONAS             101  CHACHAPOYAS     ASUNCION
# 2                  1     AMAZONAS             101  CHACHAPOYAS       BALSAS
#
#      region macroregion_inei    macroregion_minsa iso_3166_2  fips  \
# 0  AMAZONAS          ORIENTE  MACROREGION ORIENTE     PE-AMA     1
# 1  AMAZONAS          ORIENTE  MACROREGION ORIENTE     PE-AMA     1
# 2  AMAZONAS          ORIENTE  MACROREGION ORIENTE     PE-AMA     1
#
#    superficie  altitud  latitud  longitud
# 0       154.0   2338.0  -6,2294  -77,8728
# ...

# %% [markdown]
# Explorar Base de datos

# %%
## Column: Obtenemos el nombre de las columnas
## Non-null Count: si es que hay valores faltantes (missing values)  y 
## Dtype: para el tipo de cada una de las columnas 
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1893 entries, 0 to 1892
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CONCATENADOS       1893 non-null   object
#  1   id_ubigeo          1893 non-null   int64
#  2   ubigeo_reniec      1892 non-null   float64
#  3   ubigeo_inei        1892 non-null   float64
#  4   departamento_inei  1893 non-null   int64
#  5   departamento       1893 non-null   object
#  6   provincia_inei     1893 non-null   int64
#  7   provincia          1893 non-null   object
#  8   distrito           1893 non-null   object
#  9   region             1893 non-null   object
#  10  macroregion_inei   1893 non-null   object
#  11  macroregion_minsa  1893 non-null   object
#  12  iso_3166_2         1893 non-null   object
#  13  fips               1893 non-null   int64
#  14  superficie         1870 non-null   float64
#  15  altitud            1874 non-null   float64
# ...

# %%
### Nos ayuda a ver las dimensiones de nuestra base de datos. 
ndf.shape
# Out:
# (1893, 18)

# %%
##Medidas
ndf.describe()
# Out:
#          id_ubigeo  ubigeo_reniec    ubigeo_inei  departamento_inei  \
# count  1893.000000    1892.000000    1892.000000        1893.000000
# mean    947.301109  101261.235729  106841.872093          10.633386
# std     546.971013   64125.682432   67148.167215           6.723219
# min       1.000000   10101.000000   10101.000000           1.000000
# 25%     474.000000   50308.750000   50403.750000           5.000000
# 50%     947.000000   90403.500000  100316.500000          10.000000
# 75%    1421.000000  140719.250000  150806.250000          15.000000
# max    1894.000000  250401.000000  250401.000000          25.000000
#
#        provincia_inei         fips    superficie      altitud
# count     1893.000000  1893.000000   1870.000000  1874.000000
# mean      1068.731643    10.889065    684.887166  2237.099787
# std        671.518003     7.084088   1910.241819  1386.947777
# min        101.000000     1.000000      2.000000     5.000000
# ...

# %%
ndf.nunique()
# Out:
# CONCATENADOS         1893
# id_ubigeo            1893
# ubigeo_reniec        1892
# ubigeo_inei          1892
# departamento_inei      25
# departamento           25
# provincia_inei        196
# provincia             196
# distrito             1733
# region                 26
# macroregion_inei        5
# macroregion_minsa       5
# iso_3166_2             26
# fips                   26
# superficie            821
# altitud              1364
# latitud              1836
# longitud             1805
# dtype: int64

# %%
nomb_variables = ndf.columns

# %%
for nomb in nomb_variables:
    print(nomb)
# Out:
# CONCATENADOS
# id_ubigeo
# ubigeo_reniec
# ubigeo_inei
# departamento_inei
# departamento
# provincia_inei
# provincia
# distrito
# region
# macroregion_inei
# macroregion_minsa
# iso_3166_2
# fips
# superficie
# altitud
# latitud
# longitud

# %% [markdown]
# Seleccion de datos

# %%
##Forma 1
ndf.provincia
# Out:
# 0       CHACHAPOYAS
# 1       CHACHAPOYAS
# 2       CHACHAPOYAS
# 3       CHACHAPOYAS
# 4       CHACHAPOYAS
#            ...
# 1888         TUMBES
# 1889         TUMBES
# 1890         TUMBES
# 1891         TUMBES
# 1892         TUMBES
# Name: provincia, Length: 1893, dtype: object

# %%
##Forma 2
ndf['provincia']
# Out:
# 0       CHACHAPOYAS
# 1       CHACHAPOYAS
# 2       CHACHAPOYAS
# 3       CHACHAPOYAS
# 4       CHACHAPOYAS
#            ...
# 1888         TUMBES
# 1889         TUMBES
# 1890         TUMBES
# 1891         TUMBES
# 1892         TUMBES
# Name: provincia, Length: 1893, dtype: object

# %%
ndf['nombre provincia'] = ndf['provincia']

# %%
ndf['nombre provincia']
# Out:
# 0       CHACHAPOYAS
# 1       CHACHAPOYAS
# 2       CHACHAPOYAS
# 3       CHACHAPOYAS
# 4       CHACHAPOYAS
#            ...
# 1888         TUMBES
# 1889         TUMBES
# 1890         TUMBES
# 1891         TUMBES
# 1892         TUMBES
# Name: nombre provincia, Length: 1893, dtype: object

# %%
##Contar los valores únicos de una sola columna, en este caso podriamos notar cuantos distritos tiene las provincias

ndf['provincia'].value_counts()
# Out:
# LIMA                         44
# JAUJA                        34
# YAUYOS                       33
# HUAROCHIRI                   32
# AREQUIPA                     29
#                              ..
# VIRU                          3
# CHEPEN                        3
# CARLOS FERMIN FITZCARRALD     3
# ASUNCION                      2
# PURUS                         1
# Name: provincia, Length: 196, dtype: int64

# %% [markdown]
# Seleccionando un grupo de columnas

# %%
ndf.columns
# Out:
# Index(['CONCATENADOS', 'id_ubigeo', 'ubigeo_reniec', 'ubigeo_inei',
#        'departamento_inei', 'departamento', 'provincia_inei', 'provincia',
#        'distrito', 'region', 'macroregion_inei', 'macroregion_minsa',
#        'iso_3166_2', 'fips', 'superficie', 'altitud', 'latitud', 'longitud',
#        'nombre provincia'],
#       dtype='object')

# %%
ubigeo_combinacion= ['departamento', 'provincia', 'distrito']

# %%
print(ndf[ubigeo_combinacion])
# Out:
#      departamento    provincia               distrito
# 0        AMAZONAS  CHACHAPOYAS            CHACHAPOYAS
# 1        AMAZONAS  CHACHAPOYAS               ASUNCION
# 2        AMAZONAS  CHACHAPOYAS                 BALSAS
# 3        AMAZONAS  CHACHAPOYAS                  CHETO
# 4        AMAZONAS  CHACHAPOYAS              CHILIQUIN
# ...           ...          ...                    ...
# 1888       TUMBES       TUMBES               CORRALES
# 1889       TUMBES       TUMBES                LA CRUZ
# 1890       TUMBES       TUMBES     PAMPAS DE HOSPITAL
# 1891       TUMBES       TUMBES            SAN JACINTO
# 1892       TUMBES       TUMBES  SAN JUAN DE LA VIRGEN
#
# [1893 rows x 3 columns]

# %%
type(ndf['departamento'])
# Out:
# pandas.core.series.Series

# %%
Seleccionar un grupo de filas

# %%
##Forma 1: iloc
ndf.iloc[0]
# Out:
# CONCATENADOS         AMAZONASCHACHAPOYASCHACHAPOYAS
# id_ubigeo                                         1
# ubigeo_reniec                               10101.0
# ubigeo_inei                                 10101.0
# departamento_inei                                 1
# departamento                               AMAZONAS
# provincia_inei                                  101
# provincia                               CHACHAPOYAS
# distrito                                CHACHAPOYAS
# region                                     AMAZONAS
# macroregion_inei                            ORIENTE
# macroregion_minsa               MACROREGION ORIENTE
# iso_3166_2                                   PE-AMA
# fips                                              1
# superficie                                    154.0
# altitud                                      2338.0
# latitud                                     -6,2294
# longitud                                   -77,8728
# ...

# %%
##Seleccionando especificas
ndf.iloc[[10,13,30]]
# Out:
#                       CONCATENADOS  id_ubigeo  ubigeo_reniec  ubigeo_inei  \
# 10      AMAZONASCHACHAPOYASLEVANTO         11        10111.0      10111.0
# 13  AMAZONASCHACHAPOYASMOLINOPAMPA         14        10114.0      10114.0
# 30          AMAZONASBONGARACOROSHA         31        10302.0      10304.0
#
#     departamento_inei departamento  provincia_inei    provincia     distrito  \
# 10                  1     AMAZONAS             101  CHACHAPOYAS      LEVANTO
# 13                  1     AMAZONAS             101  CHACHAPOYAS  MOLINOPAMPA
# 30                  1     AMAZONAS             103      BONGARA      COROSHA
#
#       region macroregion_inei    macroregion_minsa iso_3166_2  fips  \
# 10  AMAZONAS          ORIENTE  MACROREGION ORIENTE     PE-AMA     1
# 13  AMAZONAS          ORIENTE  MACROREGION ORIENTE     PE-AMA     1
# 30  AMAZONAS          ORIENTE  MACROREGION ORIENTE     PE-AMA     1
#
#     superficie  altitud  latitud  longitud nombre provincia
# ...

# %%
ndf_ind = ndf.set_index('departamento')

# %%
ndf_ind.head(5)
# Out:
#                                 CONCATENADOS  id_ubigeo  ubigeo_reniec  \
# departamento
# AMAZONAS      AMAZONASCHACHAPOYASCHACHAPOYAS          1        10101.0
# AMAZONAS         AMAZONASCHACHAPOYASASUNCION          2        10102.0
# AMAZONAS           AMAZONASCHACHAPOYASBALSAS          3        10103.0
# AMAZONAS            AMAZONASCHACHAPOYASCHETO          4        10104.0
# AMAZONAS        AMAZONASCHACHAPOYASCHILIQUIN          5        10105.0
#
#               ubigeo_inei  departamento_inei  provincia_inei    provincia  \
# departamento
# AMAZONAS          10101.0                  1             101  CHACHAPOYAS
# AMAZONAS          10102.0                  1             101  CHACHAPOYAS
# AMAZONAS          10103.0                  1             101  CHACHAPOYAS
# AMAZONAS          10104.0                  1             101  CHACHAPOYAS
# AMAZONAS          10105.0                  1             101  CHACHAPOYAS
#
# ...

# %%
columnas = ["departamento", "provincia", "distrito"]
ndf.loc[:, columnas]
# Out:
#      departamento    provincia               distrito
# 0        AMAZONAS  CHACHAPOYAS            CHACHAPOYAS
# 1        AMAZONAS  CHACHAPOYAS               ASUNCION
# 2        AMAZONAS  CHACHAPOYAS                 BALSAS
# 3        AMAZONAS  CHACHAPOYAS                  CHETO
# 4        AMAZONAS  CHACHAPOYAS              CHILIQUIN
# ...           ...          ...                    ...
# 1888       TUMBES       TUMBES               CORRALES
# 1889       TUMBES       TUMBES                LA CRUZ
# 1890       TUMBES       TUMBES     PAMPAS DE HOSPITAL
# 1891       TUMBES       TUMBES            SAN JACINTO
# 1892       TUMBES       TUMBES  SAN JUAN DE LA VIRGEN
#
# [1893 rows x 3 columns]

# %%
ndf.loc[0:10, columnas]
# Out:
#    departamento    provincia     distrito
# 0      AMAZONAS  CHACHAPOYAS  CHACHAPOYAS
# 1      AMAZONAS  CHACHAPOYAS     ASUNCION
# 2      AMAZONAS  CHACHAPOYAS       BALSAS
# 3      AMAZONAS  CHACHAPOYAS        CHETO
# 4      AMAZONAS  CHACHAPOYAS    CHILIQUIN
# 5      AMAZONAS  CHACHAPOYAS  CHUQUIBAMBA
# 6      AMAZONAS  CHACHAPOYAS      GRANADA
# 7      AMAZONAS  CHACHAPOYAS      HUANCAS
# 8      AMAZONAS  CHACHAPOYAS     LA JALCA
# 9      AMAZONAS  CHACHAPOYAS   LEIMEBAMBA
# 10     AMAZONAS  CHACHAPOYAS      LEVANTO

# %% [markdown]
# Filtrar informacion

# %%
cond = ndf['ubigeo_reniec'] > 20000
ndf[cond]
# Out:
#                            CONCATENADOS  id_ubigeo  ubigeo_reniec  \
# 84                   ANCASHHUARAZHUARAZ         85        20101.0
# 85               ANCASHHUARAZCOCHABAMBA         86        20103.0
# 86               ANCASHHUARAZCOLCABAMBA         87        20104.0
# 87                 ANCASHHUARAZHUANCHAY         88        20105.0
# 88            ANCASHHUARAZINDEPENDENCIA         89        20102.0
# ...                                 ...        ...            ...
# 1888               TUMBESTUMBESCORRALES       1847       230102.0
# 1889                TUMBESTUMBESLA CRUZ       1848       230103.0
# 1890     TUMBESTUMBESPAMPAS DE HOSPITAL       1849       230104.0
# 1891            TUMBESTUMBESSAN JACINTO       1850       230105.0
# 1892  TUMBESTUMBESSAN JUAN DE LA VIRGEN       1851       230106.0
#
#       ubigeo_inei  departamento_inei departamento  provincia_inei provincia  \
# 84        20101.0                  2       ANCASH             201    HUARAZ
# ...

# %% [markdown]
# Limpieza de datos

# %%
ndf.sort_values("id_ubigeo", inplace = True)
ndf.head(5)
# Out:
#                      CONCATENADOS  id_ubigeo  ubigeo_reniec  ubigeo_inei  \
# 0  AMAZONASCHACHAPOYASCHACHAPOYAS          1        10101.0      10101.0
# 1     AMAZONASCHACHAPOYASASUNCION          2        10102.0      10102.0
# 2       AMAZONASCHACHAPOYASBALSAS          3        10103.0      10103.0
# 3        AMAZONASCHACHAPOYASCHETO          4        10104.0      10104.0
# 4    AMAZONASCHACHAPOYASCHILIQUIN          5        10105.0      10105.0
#
#    departamento_inei departamento  provincia_inei    provincia     distrito  \
# 0                  1     AMAZONAS             101  CHACHAPOYAS  CHACHAPOYAS
# 1                  1     AMAZONAS             101  CHACHAPOYAS     ASUNCION
# 2                  1     AMAZONAS             101  CHACHAPOYAS       BALSAS
# 3                  1     AMAZONAS             101  CHACHAPOYAS        CHETO
# 4                  1     AMAZONAS             101  CHACHAPOYAS    CHILIQUIN
#
#      region macroregion_inei    macroregion_minsa iso_3166_2  fips  \
# ...

# %%
ndf.sort_values("id_ubigeo",ascending = False,  inplace = True)
ndf.head(5)
# Out:
#                              CONCATENADOS  id_ubigeo  ubigeo_reniec  \
# 1508  LORETOMAYNASTENIENTE MANUEL CLAVERO       1894       150114.0
# 1507                 LORETOMAYNASPUTUMAYO       1893       150107.0
# 1506         SAN MARTINTOCACHESANTA LUCIA       1892       210806.0
# 1505            APURIMACCHINCHEROSAHUAYRO       1891        30712.0
# 1504    CUSCOLA CONVENCIONUNION ASHÁNINKA       1890        70919.0
#
#       ubigeo_inei  departamento_inei departamento  provincia_inei  \
# 1508     160114.0                 16       LORETO            1601
# 1507     160109.0                 16       LORETO            1601
# 1506     221006.0                 22   SAN MARTIN            2210
# 1505      30612.0                  3     APURIMAC             306
# 1504      80918.0                  8        CUSCO             809
#
#           provincia                 distrito      region macroregion_inei  \
# 1508         MAYNAS  TENIENTE MANUEL CLAVERO      LORETO          ORIENTE
# ...

# %% [markdown]
# Cambiar de nombre

# %%
ndf2 = ndf.copy(deep = True)

# %%
ndf2.columns
# Out:
# Index(['CONCATENADOS', 'id_ubigeo', 'ubigeo_reniec', 'ubigeo_inei',
#        'departamento_inei', 'departamento', 'provincia_inei', 'provincia',
#        'distrito', 'region', 'macroregion_inei', 'macroregion_minsa',
#        'iso_3166_2', 'fips', 'superficie', 'altitud', 'latitud', 'longitud'],
#       dtype='object')

# %%
nuevos_nombres = {'ubigeo_reniec': 'reniec', 'ubigeo_inei' : 'inei'}
ndf2.rename(columns = nuevos_nombres, inplace = True)

# %%
ndf2.columns
# Out:
# Index(['CONCATENADOS', 'id_ubigeo', 'reniec', 'inei', 'departamento_inei',
#        'departamento', 'provincia_inei', 'provincia', 'distrito', 'region',
#        'macroregion_inei', 'macroregion_minsa', 'iso_3166_2', 'fips',
#        'superficie', 'altitud', 'latitud', 'longitud'],
#       dtype='object')

# %% [markdown]
# Cambio de valores en variables

# %%
ndf2.loc[ndf2['macroregion_inei'] == 'ORIENTE', 'macroregion_inei'] = 'ESTE'
ndf2.head(5)
# Out:
#                      CONCATENADOS  id_ubigeo   reniec     inei  \
# 0  AMAZONASCHACHAPOYASCHACHAPOYAS          1  10101.0  10101.0
# 1     AMAZONASCHACHAPOYASASUNCION          2  10102.0  10102.0
# 2       AMAZONASCHACHAPOYASBALSAS          3  10103.0  10103.0
# 3        AMAZONASCHACHAPOYASCHETO          4  10104.0  10104.0
# 4    AMAZONASCHACHAPOYASCHILIQUIN          5  10105.0  10105.0
#
#    departamento_inei departamento  provincia_inei    provincia     distrito  \
# 0                  1     AMAZONAS             101  CHACHAPOYAS  CHACHAPOYAS
# 1                  1     AMAZONAS             101  CHACHAPOYAS     ASUNCION
# 2                  1     AMAZONAS             101  CHACHAPOYAS       BALSAS
# 3                  1     AMAZONAS             101  CHACHAPOYAS        CHETO
# 4                  1     AMAZONAS             101  CHACHAPOYAS    CHILIQUIN
#
#      region macroregion_inei    macroregion_minsa iso_3166_2  fips  \
# ...

# %% [markdown]
# Nueva Variable

# %%
ndf['nueva columna'] = True
ndf.head(3)
# Out:
#                      CONCATENADOS  id_ubigeo  ubigeo_reniec  ubigeo_inei  \
# 0  AMAZONASCHACHAPOYASCHACHAPOYAS          1        10101.0      10101.0
# 1     AMAZONASCHACHAPOYASASUNCION          2        10102.0      10102.0
# 2       AMAZONASCHACHAPOYASBALSAS          3        10103.0      10103.0
#
#    departamento_inei departamento  provincia_inei    provincia     distrito  \
# 0                  1     AMAZONAS             101  CHACHAPOYAS  CHACHAPOYAS
# 1                  1     AMAZONAS             101  CHACHAPOYAS     ASUNCION
# 2                  1     AMAZONAS             101  CHACHAPOYAS       BALSAS
#
#      region macroregion_inei    macroregion_minsa iso_3166_2  fips  \
# 0  AMAZONAS          ORIENTE  MACROREGION ORIENTE     PE-AMA     1
# 1  AMAZONAS          ORIENTE  MACROREGION ORIENTE     PE-AMA     1
# 2  AMAZONAS          ORIENTE  MACROREGION ORIENTE     PE-AMA     1
#
#    superficie  altitud  latitud  longitud  nueva columna
# ...

# %%
Merge

# %%
ndf_1 = ndf[['CONCATENADOS', 'nueva columna']]

ndf_2 = ndf2[['CONCATENADOS', 'id_ubigeo']]

# %%
resultado_merge = pd.merge(ndf_1,
                     ndf_2,
                    left_on = 'CONCATENADOS',
                    right_on = 'CONCATENADOS',
                    how = 'inner', indicator = True)
resultado_merge
# Out:
#                              CONCATENADOS  nueva columna  id_ubigeo _merge
# 0          AMAZONASCHACHAPOYASCHACHAPOYAS           True          1   both
# 1             AMAZONASCHACHAPOYASASUNCION           True          2   both
# 2               AMAZONASCHACHAPOYASBALSAS           True          3   both
# 3                AMAZONASCHACHAPOYASCHETO           True          4   both
# 4            AMAZONASCHACHAPOYASCHILIQUIN           True          5   both
# ...                                   ...            ...        ...    ...
# 1888    CUSCOLA CONVENCIONUNION ASHÁNINKA           True       1890   both
# 1889            APURIMACCHINCHEROSAHUAYRO           True       1891   both
# 1890         SAN MARTINTOCACHESANTA LUCIA           True       1892   both
# 1891                 LORETOMAYNASPUTUMAYO           True       1893   both
# 1892  LORETOMAYNASTENIENTE MANUEL CLAVERO           True       1894   both
#
# [1893 rows x 4 columns]
